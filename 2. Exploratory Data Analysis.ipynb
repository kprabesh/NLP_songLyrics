# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # 1. Top words in the lyrics

# %% [raw]
# 1. Top words in the lyrics of the five songs
# 2. Unique words used in the five songs
# 3. Level of profanity in the five snogs
#
# In terminal type the following commands separately to install these packages:
# conda install -c conda-forge wordcloud
# conda install -c conda-forge textblob
# conda install -c conda-forge gensim

# %%
#Read document term matrix using pandas
import pandas as pd
data= pd.read_pickle("dtm.pkl")
data=data.transpose()
data.head(5)
# Out:
#         327  Block Party  Dangerookipawaa freestyle  I like it  \
# abu       0            0                          1          0
# ac        1            0                          0          0
# accent    0            0                          0          1
# active    0            0                          0          1
# adjust    1            0                          0          0
#
#         Leader of Delinquents  Old town road  Shape of you
# abu                         0              0             0
# ac                          0              0             0
# accent                      0              0             0
# active                      0              0             0
# adjust                      0              0             0

# %%
# Top 30 words on the basis of count in the lyrics of the songs
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {'327': [('im', 25),
#   ('prayed', 17),
#   ('yeah', 17),
#   ('ayy', 14),
#   ('paris', 12),
#   ('swear', 12),
#   ('boom', 9),
#   ('row', 8),
#   ('face', 8),
#   ('mangoes', 8),
#   ('caseload', 8),
#   ('ankles', 8),
#   ('got', 7),
#   ('niggas', 6),
#   ('good', 6),
#   ('way', 6),
#   ('shit', 5),
#   ('places', 4),
#   ('silks', 4),
#   ('casablanca', 4),
#   ('baby', 4),
#   ('oranges', 4),
#   ('need', 4),
#   ('don', 4),
#   ('bah', 4),
#   ('ah', 4),
#   ('fuck', 4),
#   ('model', 4),
#   ('offwhite', 4),
#   ('used', 4)],
#  'Block Party': [('block', 11),
#   ('party', 10),
#   ('shit', 9),
#   ('remind', 8),
#   ('got', 6),
#   ('bout', 4),
#   ('gon', 4),
#   ('dem', 4),
#   ('just', 4),
#   ('cause', 4),
#   ('im', 3),
#   ('know', 3),
#   ('wanna', 3),
#   ('outside', 3),
#   ('dont', 3),
#   ('dope', 3),
#   ('high', 3),
#   ('wont', 3),
#   ('look', 2),
#   ('charcoal', 2),
#   ('smell', 2),
#   ('barbecue', 2),
#   ('vibe', 2),
#   ('drinks', 2),
#   ('love', 2),
#   ('deh', 2),
#   ('ting', 2),
#   ('grill', 2),
#   ('grilled', 2),
#   ('ice', 2)],
#  'Dangerookipawaa freestyle': [('yeah', 21),
#   ('im', 8),
#   ('like', 8),
#   ('got', 5),
#   ('uh', 5),
#   ('aint', 4),
#   ('baby', 3),
#   ('ayy', 2),
#   ('monkey', 2),
#   ('wait', 2),
#   ('rules', 2),
#   ('nigga', 2),
#   ('bout', 2),
#   ('style', 2),
#   ('crib', 2),
#   ('know', 2),
#   ('haha', 2),
#   ('new', 2),
#   ('breakin', 2),
#   ('huh', 2),
#   ('raise', 2),
#   ('soulo', 2),
#   ('bitch', 2),
#   ('rare', 2),
#   ('man', 2),
#   ('pullin', 1),
#   ('drugs', 1),
#   ('rapper', 1),
#   ('rappers', 1),
#   ('pushin', 1)],
#  'I like it': [('like', 72),
#   ('said', 26),
#   ('gang', 12),
#   ('woo', 9),
#   ('im', 9),
#   ('yeh', 6),
#   ('enjoys', 6),
#   ('oh', 6),
#   ('whats', 5),
#   ('tell', 5),
#   ('thing', 4),
#   ('bitch', 4),
#   ('baby', 3),
#   ('bad', 3),
#   ('brains', 3),
#   ('got', 3),
#   ('certified', 3),
#   ('chain', 3),
#   ('hookah', 3),
#   ('district', 3),
#   ('know', 3),
#   ('dont', 3),
#   ('drop', 3),
#   ('blow', 3),
#   ('hes', 3),
#   ('diamond', 3),
#   ('handsome', 3),
#   ('dollars', 3),
#   ('cardi', 3),
#   ('dollar', 2)],
#  'Leader of Delinquents': [('delinquents', 16),
#   ('im', 10),
#   ('leader', 8),
#   ('mm', 6),
#   ('love', 5),
#   ('dont', 5),
#   ('cudder', 4),
#   ('shit', 4),
#   ('mad', 3),
#   ('em', 3),
#   ('fuckin', 3),
#   ('did', 3),
#   ('man', 2),
#   ('days', 2),
#   ('mind', 2),
#   ('things', 2),
#   ('theres', 2),
#   ('thats', 2),
#   ('wanna', 2),
#   ('got', 2),
#   ('gotta', 2),
#   ('god', 2),
#   ('girl', 2),
#   ('does', 2),
#   ('nigga', 2),
#   ('easy', 2),
#   ('trippin', 2),
#   ('bitch', 2),
#   ('better', 2),
#   ('face', 2)],
#  'Old town road': [('im', 13),
#   ('gonna', 12),
#   ('town', 8),
#   ('horse', 8),
#   ('tell', 8),
#   ('nothin', 8),
#   ('til', 7),
#   ('old', 7),
#   ('ride', 7),
#   ('road', 7),
#   ('ridin', 4),
#   ('got', 4),
#   ('yeah', 3),
#   ('hat', 3),
#   ('oh', 2),
#   ('sports', 2),
#   ('black', 2),
#   ('like', 2),
#   ('kio', 2),
#   ('porsche', 1),
#   ('booty', 1),
#   ('cowboy', 1),
#   ('ive', 1),
#   ('tack', 1),
#   ('fendi', 1),
#   ('cross', 1),
#   ('bras', 1),
#   ('brand', 1),
#   ('tractor', 1),
#   ('valley', 1)],
#  'Shape of you': [('come', 37),
#   ('love', 25),
#   ('oh', 24),
#   ('im', 23),
#   ('body', 17),
#   ('baby', 14),
#   ('like', 10),
#   ('day', 6),
#   ('lead', 6),
#   ('brand', 6),
#   ('shape', 6),
#   ('discovering', 6),
#   ('new', 6),
#   ('follow', 6),
#   ('talk', 4),
#   ('push', 3),
#   ('smell', 3),
#   ('pull', 3),
#   ('falling', 3),
#   ('room', 3),
#   ('sheets', 3),
#   ('night', 3),
#   ('bed', 3),
#   ('heart', 3),
#   ('magnet', 3),
#   ('know', 2),
#   ('dont', 2),
#   ('doing', 2),
#   ('say', 2),
#   ('handmade', 2)]}

# %%
# Take a look at Top 30 words again on the basis of word count in the song lyrics
for song, top_words in top_dict.items():
    print(song)
    print(', '.join([word for word, count in top_words[0:29]]))
    print('---')
# Out:
# 327
# im, prayed, yeah, ayy, paris, swear, boom, row, face, mangoes, caseload, ankles, got, niggas, good, way, shit, places, silks, casablanca, baby, oranges, need, don, bah, ah, fuck, model, offwhite
# ---
# Block Party
# block, party, shit, remind, got, bout, gon, dem, just, cause, im, know, wanna, outside, dont, dope, high, wont, look, charcoal, smell, barbecue, vibe, drinks, love, deh, ting, grill, grilled
# ---
# Dangerookipawaa freestyle
# yeah, im, like, got, uh, aint, baby, ayy, monkey, wait, rules, nigga, bout, style, crib, know, haha, new, breakin, huh, raise, soulo, bitch, rare, man, pullin, drugs, rapper, rappers
# ---
# I like it
# like, said, gang, woo, im, yeh, enjoys, oh, whats, tell, thing, bitch, baby, bad, brains, got, certified, chain, hookah, district, know, dont, drop, blow, hes, diamond, handsome, dollars, cardi
# ---
# Leader of Delinquents
# delinquents, im, leader, mm, love, dont, cudder, shit, mad, em, fuckin, did, man, days, mind, things, theres, thats, wanna, got, gotta, god, girl, does, nigga, easy, trippin, bitch, better
# ---
# Old town road
# im, gonna, town, horse, tell, nothin, til, old, ride, road, ridin, got, yeah, hat, oh, sports, black, like, kio, porsche, booty, cowboy, ive, tack, fendi, cross, bras, brand, tractor
# ---
# Shape of you
# come, love, oh, im, body, baby, like, day, lead, brand, shape, discovering, new, follow, talk, push, smell, pull, falling, room, sheets, night, bed, heart, magnet, know, dont, doing, say
# ---

# %% [raw]
# Some of the words non sensical and can be removed to make the data moore meaningful and precise.
# So, we will add those words to stop word list before creating word clouds.

# %%
#Look at the most common words among the five songs
from collections import Counter
''' pulling out top 30 words from the all lyrics'''

words = []
for song in data.columns:
    top = [word for (word, count) in top_dict[song]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['im',
#  'prayed',
#  'yeah',
#  'ayy',
#  'paris',
#  'swear',
#  'boom',
#  'row',
#  'face',
#  'mangoes',
#  'caseload',
#  'ankles',
#  'got',
#  'niggas',
#  'good',
#  'way',
#  'shit',
#  'places',
#  'silks',
#  'casablanca',
#  'baby',
#  'oranges',
#  'need',
#  'don',
#  'bah',
#  'ah',
#  'fuck',
#  'model',
#  'offwhite',
#  'used',
#  'block',
#  'party',
#  'shit',
#  'remind',
#  'got',
#  'bout',
#  'gon',
#  'dem',
#  'just',
#  'cause',
#  'im',
#  'know',
#  'wanna',
#  'outside',
#  'dont',
#  'dope',
#  'high',
#  'wont',
#  'look',
#  'charcoal',
#  'smell',
#  'barbecue',
#  'vibe',
#  'drinks',
#  'love',
#  'deh',
#  'ting',
#  'grill',
#  'grilled',
#  'ice',
#  'yeah',
#  'im',
#  'like',
#  'got',
#  'uh',
#  'aint',
#  'baby',
#  'ayy',
#  'monkey',
#  'wait',
#  'rules',
#  'nigga',
#  'bout',
#  'style',
#  'crib',
#  'know',
#  'haha',
#  'new',
#  'breakin',
#  'huh',
#  'raise',
#  'soulo',
#  'bitch',
#  'rare',
#  'man',
#  'pullin',
#  'drugs',
#  'rapper',
#  'rappers',
#  'pushin',
#  'like',
#  'said',
#  'gang',
#  'woo',
#  'im',
#  'yeh',
#  'enjoys',
#  'oh',
#  'whats',
#  'tell',
#  'thing',
#  'bitch',
#  'baby',
#  'bad',
#  'brains',
#  'got',
#  'certified',
#  'chain',
#  'hookah',
#  'district',
#  'know',
#  'dont',
#  'drop',
#  'blow',
#  'hes',
#  'diamond',
#  'handsome',
#  'dollars',
#  'cardi',
#  'dollar',
#  'delinquents',
#  'im',
#  'leader',
#  'mm',
#  'love',
#  'dont',
#  'cudder',
#  'shit',
#  'mad',
#  'em',
#  'fuckin',
#  'did',
#  'man',
#  'days',
#  'mind',
#  'things',
#  'theres',
#  'thats',
#  'wanna',
#  'got',
#  'gotta',
#  'god',
#  'girl',
#  'does',
#  'nigga',
#  'easy',
#  'trippin',
#  'bitch',
#  'better',
#  'face',
#  'im',
#  'gonna',
#  'town',
#  'horse',
#  'tell',
#  'nothin',
#  'til',
#  'old',
#  'ride',
#  'road',
#  'ridin',
#  'got',
#  'yeah',
#  'hat',
#  'oh',
#  'sports',
#  'black',
#  'like',
#  'kio',
#  'porsche',
#  'booty',
#  'cowboy',
#  'ive',
#  'tack',
#  'fendi',
#  'cross',
#  'bras',
#  'brand',
#  'tractor',
#  'valley',
#  'come',
#  'love',
#  'oh',
#  'im',
#  'body',
#  'baby',
#  'like',
#  'day',
#  'lead',
#  'brand',
#  'shape',
#  'discovering',
#  'new',
#  'follow',
#  'talk',
#  'push',
#  'smell',
#  'pull',
#  'falling',
#  'room',
#  'sheets',
#  'night',
#  'bed',
#  'heart',
#  'magnet',
#  'know',
#  'dont',
#  'doing',
#  'say',
#  'handmade']

# %%
# Now we aggregate this list, and identify the most common words along with how many routines they occur in
Counter(words).most_common()
# Out:
# [('im', 7),
#  ('got', 6),
#  ('baby', 4),
#  ('know', 4),
#  ('dont', 4),
#  ('like', 4),
#  ('yeah', 3),
#  ('shit', 3),
#  ('love', 3),
#  ('bitch', 3),
#  ('oh', 3),
#  ('ayy', 2),
#  ('face', 2),
#  ('bout', 2),
#  ('wanna', 2),
#  ('smell', 2),
#  ('nigga', 2),
#  ('new', 2),
#  ('man', 2),
#  ('tell', 2),
#  ('brand', 2),
#  ('prayed', 1),
#  ('paris', 1),
#  ('swear', 1),
#  ('boom', 1),
#  ('row', 1),
#  ('mangoes', 1),
#  ('caseload', 1),
#  ('ankles', 1),
#  ('niggas', 1),
#  ('good', 1),
#  ('way', 1),
#  ('places', 1),
#  ('silks', 1),
#  ('casablanca', 1),
#  ('oranges', 1),
#  ('need', 1),
#  ('don', 1),
#  ('bah', 1),
#  ('ah', 1),
#  ('fuck', 1),
#  ('model', 1),
#  ('offwhite', 1),
#  ('used', 1),
#  ('block', 1),
#  ('party', 1),
#  ('remind', 1),
#  ('gon', 1),
#  ('dem', 1),
#  ('just', 1),
#  ('cause', 1),
#  ('outside', 1),
#  ('dope', 1),
#  ('high', 1),
#  ('wont', 1),
#  ('look', 1),
#  ('charcoal', 1),
#  ('barbecue', 1),
#  ('vibe', 1),
#  ('drinks', 1),
#  ('deh', 1),
#  ('ting', 1),
#  ('grill', 1),
#  ('grilled', 1),
#  ('ice', 1),
#  ('uh', 1),
#  ('aint', 1),
#  ('monkey', 1),
#  ('wait', 1),
#  ('rules', 1),
#  ('style', 1),
#  ('crib', 1),
#  ('haha', 1),
#  ('breakin', 1),
#  ('huh', 1),
#  ('raise', 1),
#  ('soulo', 1),
#  ('rare', 1),
#  ('pullin', 1),
#  ('drugs', 1),
#  ('rapper', 1),
#  ('rappers', 1),
#  ('pushin', 1),
#  ('said', 1),
#  ('gang', 1),
#  ('woo', 1),
#  ('yeh', 1),
#  ('enjoys', 1),
#  ('whats', 1),
#  ('thing', 1),
#  ('bad', 1),
#  ('brains', 1),
#  ('certified', 1),
#  ('chain', 1),
#  ('hookah', 1),
#  ('district', 1),
#  ('drop', 1),
#  ('blow', 1),
#  ('hes', 1),
#  ('diamond', 1),
#  ('handsome', 1),
#  ('dollars', 1),
#  ('cardi', 1),
#  ('dollar', 1),
#  ('delinquents', 1),
#  ('leader', 1),
#  ('mm', 1),
#  ('cudder', 1),
#  ('mad', 1),
#  ('em', 1),
#  ('fuckin', 1),
#  ('did', 1),
#  ('days', 1),
#  ('mind', 1),
#  ('things', 1),
#  ('theres', 1),
#  ('thats', 1),
#  ('gotta', 1),
#  ('god', 1),
#  ('girl', 1),
#  ('does', 1),
#  ('easy', 1),
#  ('trippin', 1),
#  ('better', 1),
#  ('gonna', 1),
#  ('town', 1),
#  ('horse', 1),
#  ('nothin', 1),
#  ('til', 1),
#  ('old', 1),
#  ('ride', 1),
#  ('road', 1),
#  ('ridin', 1),
#  ('hat', 1),
#  ('sports', 1),
#  ('black', 1),
#  ('kio', 1),
#  ('porsche', 1),
#  ('booty', 1),
#  ('cowboy', 1),
#  ('ive', 1),
#  ('tack', 1),
#  ('fendi', 1),
#  ('cross', 1),
#  ('bras', 1),
#  ('tractor', 1),
#  ('valley', 1),
#  ('come', 1),
#  ('body', 1),
#  ('day', 1),
#  ('lead', 1),
#  ('shape', 1),
#  ('discovering', 1),
#  ('follow', 1),
#  ('talk', 1),
#  ('push', 1),
#  ('pull', 1),
#  ('falling', 1),
#  ('room', 1),
#  ('sheets', 1),
#  ('night', 1),
#  ('bed', 1),
#  ('heart', 1),
#  ('magnet', 1),
#  ('doing', 1),
#  ('say', 1),
#  ('handmade', 1)]

# %%
# If more than half of the songs have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 3]
add_stop_words
# Out:
# ['im', 'got', 'baby', 'know', 'dont', 'like']

# %%
# Now we will update our document-term matrix with the new list of stop words
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer

# Reading cleaned data
data_clean = pd.read_pickle('data_clean.pkl')

# Adding new stop words from our top 30 words list to previous set 
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Creating document-term matrix again
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean.Lyrics)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_stop.index = data_clean.index

# Pickle it for later use
import pickle
pickle.dump(cv, open("cv_stop.pkl", "wb"))
data_stop.to_pickle("dtm_stop.pkl")

# %%
# Now we will make some wordclouds

from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)
data.keys()
# Out:
# Index(['327', 'Block Party', 'Dangerookipawaa freestyle', 'I like it',
#        'Leader of Delinquents', 'Old town road', 'Shape of you'],
#       dtype='object')

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 6]

song_names = ['327', 'Block Party', 'Dangerookipawaa freestyle','Leader of Delinquents', 'Shape of you','Old town road','I like it']

# Create subplots for each comedian
for index, song in enumerate(data.columns):
    wc.generate(data_clean.Lyrics[song])
    
    plt.subplot(3, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(song_names[index])
    
plt.show()

# %% [raw]
# Findings:
# Shape of you, Old town road, I Like it have no swear words but other four songs use swear words a lot
# 3 of the 4 hiphop songs use their song title a lot in their lyrics
# Shape of you  and dangerookipawa freestyle does not use the song title that often in its lyrics

# %% [markdown]
# # 2. Level of Profanity in the Lyrics

# %%
# Find the count of use of profanity in the lyrics

Counter(words).most_common()
# Out:
# [('im', 7),
#  ('got', 6),
#  ('baby', 4),
#  ('know', 4),
#  ('dont', 4),
#  ('like', 4),
#  ('yeah', 3),
#  ('shit', 3),
#  ('love', 3),
#  ('bitch', 3),
#  ('oh', 3),
#  ('ayy', 2),
#  ('face', 2),
#  ('bout', 2),
#  ('wanna', 2),
#  ('smell', 2),
#  ('nigga', 2),
#  ('new', 2),
#  ('man', 2),
#  ('tell', 2),
#  ('brand', 2),
#  ('prayed', 1),
#  ('paris', 1),
#  ('swear', 1),
#  ('boom', 1),
#  ('row', 1),
#  ('mangoes', 1),
#  ('caseload', 1),
#  ('ankles', 1),
#  ('niggas', 1),
#  ('good', 1),
#  ('way', 1),
#  ('places', 1),
#  ('silks', 1),
#  ('casablanca', 1),
#  ('oranges', 1),
#  ('need', 1),
#  ('don', 1),
#  ('bah', 1),
#  ('ah', 1),
#  ('fuck', 1),
#  ('model', 1),
#  ('offwhite', 1),
#  ('used', 1),
#  ('block', 1),
#  ('party', 1),
#  ('remind', 1),
#  ('gon', 1),
#  ('dem', 1),
#  ('just', 1),
#  ('cause', 1),
#  ('outside', 1),
#  ('dope', 1),
#  ('high', 1),
#  ('wont', 1),
#  ('look', 1),
#  ('charcoal', 1),
#  ('barbecue', 1),
#  ('vibe', 1),
#  ('drinks', 1),
#  ('deh', 1),
#  ('ting', 1),
#  ('grill', 1),
#  ('grilled', 1),
#  ('ice', 1),
#  ('uh', 1),
#  ('aint', 1),
#  ('monkey', 1),
#  ('wait', 1),
#  ('rules', 1),
#  ('style', 1),
#  ('crib', 1),
#  ('haha', 1),
#  ('breakin', 1),
#  ('huh', 1),
#  ('raise', 1),
#  ('soulo', 1),
#  ('rare', 1),
#  ('pullin', 1),
#  ('drugs', 1),
#  ('rapper', 1),
#  ('rappers', 1),
#  ('pushin', 1),
#  ('said', 1),
#  ('gang', 1),
#  ('woo', 1),
#  ('yeh', 1),
#  ('enjoys', 1),
#  ('whats', 1),
#  ('thing', 1),
#  ('bad', 1),
#  ('brains', 1),
#  ('certified', 1),
#  ('chain', 1),
#  ('hookah', 1),
#  ('district', 1),
#  ('drop', 1),
#  ('blow', 1),
#  ('hes', 1),
#  ('diamond', 1),
#  ('handsome', 1),
#  ('dollars', 1),
#  ('cardi', 1),
#  ('dollar', 1),
#  ('delinquents', 1),
#  ('leader', 1),
#  ('mm', 1),
#  ('cudder', 1),
#  ('mad', 1),
#  ('em', 1),
#  ('fuckin', 1),
#  ('did', 1),
#  ('days', 1),
#  ('mind', 1),
#  ('things', 1),
#  ('theres', 1),
#  ('thats', 1),
#  ('gotta', 1),
#  ('god', 1),
#  ('girl', 1),
#  ('does', 1),
#  ('easy', 1),
#  ('trippin', 1),
#  ('better', 1),
#  ('gonna', 1),
#  ('town', 1),
#  ('horse', 1),
#  ('nothin', 1),
#  ('til', 1),
#  ('old', 1),
#  ('ride', 1),
#  ('road', 1),
#  ('ridin', 1),
#  ('hat', 1),
#  ('sports', 1),
#  ('black', 1),
#  ('kio', 1),
#  ('porsche', 1),
#  ('booty', 1),
#  ('cowboy', 1),
#  ('ive', 1),
#  ('tack', 1),
#  ('fendi', 1),
#  ('cross', 1),
#  ('bras', 1),
#  ('tractor', 1),
#  ('valley', 1),
#  ('come', 1),
#  ('body', 1),
#  ('day', 1),
#  ('lead', 1),
#  ('shape', 1),
#  ('discovering', 1),
#  ('follow', 1),
#  ('talk', 1),
#  ('push', 1),
#  ('pull', 1),
#  ('falling', 1),
#  ('room', 1),
#  ('sheets', 1),
#  ('night', 1),
#  ('bed', 1),
#  ('heart', 1),
#  ('magnet', 1),
#  ('doing', 1),
#  ('say', 1),
#  ('handmade', 1)]

# %%
# Now we isolate just those swear words
data_bad_words = data.transpose()[['shit', 'nigga', 'bitch','fuck','fuckin']]
data_profanity = pd.concat([data_bad_words.shit+data_bad_words.fuck+data_bad_words.fuckin,data_bad_words.nigga+ data_bad_words.bitch], axis=1)
data_profanity.columns = ['derogatory_word', 'curse_word']
data_profanity

##derogatory= insulting a group of people'''
##curse=expression of anger'''
# Out:
#                            derogatory_word  curse_word
# 327                                     10           5
# Block Party                             10           0
# Dangerookipawaa freestyle                1           4
# I like it                                2           4
# Leader of Delinquents                    8           4
# Old town road                            0           0
# Shape of you                             0           0

# %%
# We will display our findings in a scatterplot
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [30, 10]
song_names = ['327', 'Block Party', 'Dangerookipawaa freestyle', 'Leader of Delinquents', 'Shape of you','Old town road','I like it']


for i, word in enumerate(data_profanity.index):
    x = data_profanity.derogatory_word.loc[word]
    y = data_profanity.curse_word.loc[word]
    plt.scatter(x, y, color='blue')
    plt.text(x, y+0.003, song_names[i], fontsize=10)
    plt.xlim(-2, 20) 
    
plt.title('Number of profane words used in Songs', fontsize=20)
plt.xlabel('Number of Derogatory Words', fontsize=15)
plt.ylabel('Number of Curse Words', fontsize=15)

plt.show()

# %% [raw]
# Findings:
# 1. Block Party and Dangerookipawaa freestyle are extremes of the dataset. They both strech the data in opposite directions, hence the data is a good collection.
# 2. Popular Hiphop songs of 2020 tend to have more profanity than pop songs
# 3. There are two kinds of profanity that hiphop songs can follow, either be more derogatory like Block Party or be more cursing like Dangerookipawaa freestyle
# 4. More Pop songs are needed to draw a conclsive finding
