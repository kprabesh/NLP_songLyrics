# %% [markdown]
# # Text Generation , Markov Chain

# %% [raw]
# Assumption: Next word is only dependent on the previous word.
# Basic Text Generation.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                                       Lyrics
# 327                        [Chorus: Billie Essco & Westside Gunn]\nLook, ...
# Block Party                [Intro: CJ Fly]\nStatik Selektah\nEvery time I...
# Dangerookipawaa freestyle  [Part I]\n\n[Intro]\nYeah\nYeah\nYeah, ayy, ma...
# I like it                  [Intro]\nYeah baby, I like it like that\nYou g...
# Leader of Delinquents      [Intro]\nMm (Yeah), mm, mm\n(This is not a tes...
# Old town road              [Intro: Billy Ray Cyrus]\nOh, oh-oh\nOh\n\n[Re...
# Shape of you               [Verse 1]\nThe club isn't the best place to fi...

# %%
# Extract only I like it song lyrics
cardi_text = data.Lyrics.loc['I like it']
cardi_text[:300]
# Out:
# "[Intro]\nYeah baby, I like it like that\nYou gotta believe me when I tell you\nI said I like it like that\nYou gotta believe me when I tell you\nI said I like it like—\n\n[Verse 1: Cardi B]\nNow I like dollars, I like diamonds, I like stunting, I like shining\nI like million dollar deals, where's my pen? Bit"

# %% [markdown]
# # Build Markov Chain Function

# %% [raw]
# We are creating a dictionary with:
# 1. Keys= all of the words in corpus
# 2. values= words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for I like it, take a look at it
cardi_dict = markov_chain(cardi_text)
cardi_dict
# Out:
# {'[Intro]\nYeah': ['baby,'],
#  'baby,': ['I', 'be,'],
#  'I': ['like',
#   'tell',
#   'like',
#   'tell',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'put',
#   'do',
#   "can't\nThey",
#   'can\nEating',
#   'run',
#   'like',
#   'like',
#   'like',
#   'like',
#   'need',
#   'like',
#   'like',
#   'like',
#   'like',
#   'got',
#   'like',
#   'got',
#   'like',
#   'like',
#   'like',
#   'like',
#   'need',
#   'like',
#   'like',
#   'like',
#   'like',
#   'got',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like'],
#  'like': ['it',
#   'that\nYou',
#   'it',
#   'that\nYou',
#   'it',
#   'dollars,',
#   'diamonds,',
#   'stunting,',
#   'shining\nI',
#   'million',
#   'those',
#   'socks\nI',
#   'going',
#   'texts',
#   'proving',
#   'Mario',
#   'cardio\nOh,',
#   'it',
#   'that)\nCertified,',
#   'it',
#   'it',
#   'that)\nOh',
#   'it)\nOh',
#   'it',
#   'that)\nBeat',
#   'piñatas',
#   'it',
#   'it',
#   'that)\nBad',
#   'it)\nCardi',
#   'Eddie,',
#   'Boricuas,',
#   'Cubans',
#   'the',
#   'how',
#   'it',
#   'that)\nBad',
#   'it',
#   'it',
#   'that)\nOh,',
#   'it)\nOh,',
#   'it',
#   'that)\nBeat',
#   'piñatas',
#   'it',
#   'it',
#   'that)\nBad',
#   'it)\n\n[Verse',
#   'Jimmy',
#   "I'm",
#   'the',
#   'it',
#   'that\nI',
#   'it',
#   'that',
#   'it',
#   'that',
#   'it',
#   'that\n\n[Chorus:',
#   'it',
#   'that)\nCertified,',
#   'it',
#   'it',
#   'that)\nOh',
#   'it)'],
#  'it': ['like',
#   'like',
#   'like—\n\n[Verse',
#   'like',
#   'like—)\nDrop',
#   'like',
#   'like',
#   'up',
#   'like—)\nTell',
#   'like',
#   'like',
#   'like—)\nDrop',
#   'like',
#   'like',
#   'up',
#   'like—)\nTell',
#   'like',
#   'and',
#   '(enjoys',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like—)\nDrop',
#   'like'],
#  'that\nYou': ['gotta', 'gotta'],
#  'gotta': ['believe', 'believe'],
#  'believe': ['me', 'me'],
#  'me': ['when',
#   'when',
#   'Cardi',
#   'Cardi',
#   'but',
#   '(amen)\nGuerrero',
#   'the',
#   'and',
#   'in',
#   '(hey)\nI'],
#  'when': ['I', 'I', 'they'],
#  'tell': ['you\nI', 'you\nI', 'them,'],
#  'you\nI': ['said', 'said'],
#  'said': ['I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I'],
#  'like—\n\n[Verse': ['1:'],
#  '1:': ['Cardi'],
#  'Cardi': ['B]\nNow',
#   'Bardi,',
#   'B,',
#   'B]\nDiamond',
#   'B',
#   'B]\nI',
#   'B]\nDiamond'],
#  'B]\nNow': ['I'],
#  'dollars,': ['I'],
#  'diamonds,': ['I'],
#  'stunting,': ['I'],
#  'shining\nI': ['like'],
#  'million': ['dollar'],
#  'dollar': ['deals,', 'bills'],
#  'deals,': ["where's"],
#  "where's": ['my'],
#  'my': ['pen?', 'watch\nI', 'exes', 'coins', 'house,'],
#  'pen?': ['Bitch'],
#  'Bitch': ["I'm"],
#  "I'm": ["signin'\nI", 'sorry', 'gang,', 'gang,', 'Lady', 'like', 'gang,'],
#  "signin'\nI": ['like'],
#  'those': ['Balenciagas,'],
#  'Balenciagas,': ['the'],
#  'the': ['ones',
#   'jeweler,',
#   "stu',",
#   'coupe',
#   'roof\nFlexing',
#   "Lam'\nTold",
#   'chain',
#   'top',
#   'brains',
#   'dollars',
#   'driver,',
#   'curtains',
#   'trigger',
#   'trigger!)\nYou',
#   "Jordan's,",
#   'club',
#   'bank',
#   'new',
#   'closet',
#   'Gucci',
#   'race',
#   'accent',
#   'Colombians',
#   'ass',
#   'Dominican',
#   'Venezuelans',
#   'briefcase',
#   'bass',
#   'club',
#   'riot',
#   'chain',
#   'top',
#   'brains',
#   'dollars',
#   'driver,',
#   'curtains',
#   'sugar',
#   'hookah',
#   'entrance',
#   'Testarossa',
#   'one',
#   'thing,',
#   'thing',
#   'one',
#   'chain',
#   'top',
#   'brains,'],
#  'ones': ['that'],
#  'that': ['look', 'bitch', '(rrr)\nI', '(woo)\nI'],
#  'look': ['like'],
#  'socks\nI': ['like'],
#  'going': ['to', 'on?)\nI'],
#  'to': ['the', 'me\nI', 'diet', 'inside', 'hell,'],
#  'jeweler,': ['I'],
#  'put': ['rocks'],
#  'rocks': ['all'],
#  'all': ['in', 'the'],
#  'in': ['my',
#   'the',
#   'the',
#   'the',
#   'the',
#   'Latino',
#   'the',
#   'Plaza',
#   'the',
#   'the',
#   'the',
#   'covers',
#   'the'],
#  'watch\nI': ['like'],
#  'texts': ['from'],
#  'from': ['my'],
#  'exes': ['when'],
#  'they': ['want', 'say', 'call', 'reload,', 'gift', 'fuck', 'receive'],
#  'want': ['a'],
#  'a': ['second', 'Somali,'],
#  'second': ['chance\nI'],
#  'chance\nI': ['like'],
#  'proving': ['niggas'],
#  'niggas': ['wrong,'],
#  'wrong,': ['I'],
#  'do': ['what'],
#  'what': ['they', 'you'],
#  'say': ['I'],
#  "can't\nThey": ['call'],
#  'call': ['me', 'me'],
#  'Bardi,': ['banging'],
#  'banging': ['body\nSpicy'],
#  'body\nSpicy': ['mami,'],
#  'mami,': ['hot'],
#  'hot': ['tamale\nHotter'],
#  'tamale\nHotter': ['than'],
#  'than': ['a'],
#  'Somali,': ['fur'],
#  'fur': ['coat,'],
#  'coat,': ['Ferrari\nHop'],
#  'Ferrari\nHop': ['out'],
#  'out': ['the'],
#  "stu',": ['jump'],
#  'jump': ['in'],
#  'coupe': ['(the'],
#  '(the': ['coupe)\nBig'],
#  'coupe)\nBig': ['Dipper'],
#  'Dipper': ['on'],
#  'on': ['top', 'bitches'],
#  'top': ['of', 'and', 'and', 'and'],
#  'of': ['the', 'the', 'Billboard'],
#  'roof\nFlexing': ['on'],
#  'bitches': ['as'],
#  'as': ['hard', 'I'],
#  'hard': ['as'],
#  'can\nEating': ['halal,'],
#  'halal,': ['driving'],
#  'driving': ['the'],
#  "Lam'\nTold": ['that'],
#  'bitch': ["I'm", 'make', 'make'],
#  'sorry': ["though\n'Bout"],
#  "though\n'Bout": ['my'],
#  'coins': ['like'],
#  'Mario': ['(Mario)\nYeah'],
#  '(Mario)\nYeah': ['they'],
#  'B,': ['I'],
#  'run': ['this'],
#  'this': ['shit'],
#  'shit': ['like'],
#  'cardio\nOh,': ['damn\n\n[Chorus:'],
#  'damn\n\n[Chorus:': ['Cardi'],
#  'B]\nDiamond': ['district', 'district'],
#  'district': ['in', 'in', 'in'],
#  'chain': ['(I', '(I', '(I'],
#  '(I': ['said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said'],
#  'that)\nCertified,': ['know', 'know'],
#  'know': ["I'm", "I'm", "I'm"],
#  'gang,': ['gang,',
#   'gang,',
#   'gang',
#   'gang,',
#   'yeh\nI',
#   'gang,',
#   'gang,',
#   'gang',
#   'gang'],
#  'gang': ['(I', '(I', '(I'],
#  'like—)\nDrop': ['the', 'the', 'the'],
#  'and': ['blow', 'the', 'blow', 'fell', 'enjoys', 'the', 'blow'],
#  'blow': ['the', 'the', 'the'],
#  'brains': ['(I', '(I'],
#  'that)\nOh': ["he's", "he's"],
#  "he's": ['so', 'so', 'so'],
#  'so': ['handsome,', 'handsome,', 'handsome,'],
#  'handsome,': ["what's", "what's", "what's"],
#  "what's": ['his', 'his', 'his'],
#  'his': ['name?', 'name?', 'name?'],
#  'name?': ['(I', '(I', '(I'],
#  'it)\nOh': ['I'],
#  'need': ['the', 'the'],
#  'dollars': ['(I', '(I'],
#  'that)\nBeat': ['it', 'it'],
#  'up': ['like', 'like'],
#  'piñatas': ['(I', '(I'],
#  'like—)\nTell': ['the', 'the'],
#  'driver,': ['close', 'close'],
#  'close': ['the', 'the'],
#  'curtains': ['(I', '(I'],
#  'that)\nBad': ['bitch', 'Bunny,', 'bitch'],
#  'make': ['him', 'him'],
#  'him': ['nervous', 'nervous'],
#  'nervous': ['(I', '(I'],
#  'it)\nCardi': ['B\n\n[Verse'],
#  'B\n\n[Verse': ['2:'],
#  '2:': ['Bad'],
#  'Bad': ['Bunny]\nThey', 'Bunny]\nDiamond'],
#  'Bunny]\nThey': ['reload,'],
#  'reload,': ['they', 'but'],
#  'but': ["don't", 'in', 'Jesus'],
#  "don't": ['pull', 'play', 'leave'],
#  'pull': ['the'],
#  'trigger': ['(pull'],
#  '(pull': ['the'],
#  'trigger!)\nYou': ['buy'],
#  'buy': ['all'],
#  "Jordan's,": ['fool,'],
#  'fool,': ['they'],
#  'gift': ['them'],
#  'them': ['to'],
#  'me\nI': ['spend'],
#  'spend': ['in'],
#  'club': ['(woo),', 'and'],
#  '(woo),': ['what'],
#  'you': ['have', 'the', 'have', 'go', 'have'],
#  'have': ['in', 'seen', 'heard'],
#  'bank': ['(yeh)\nThis'],
#  '(yeh)\nThis': ['is'],
#  'is': ['the', 'forbidden'],
#  'new': ['religion,'],
#  'religion,': ['bang,'],
#  'bang,': ['in'],
#  'Latino': ['gang,'],
#  'yeh\nI': ['try'],
#  'try': ['to'],
#  'diet': ['(yeh),'],
#  '(yeh),': ['but'],
#  'closet': ['I'],
#  'got': ['too', 'Claritin\nI', 'the'],
#  'too': ['much'],
#  'much': ['fat'],
#  'fat': ['(woo!)\nI'],
#  '(woo!)\nI': ['already'],
#  'already': ['moved'],
#  'moved': ['the'],
#  'Gucci': ['to'],
#  'inside': ['my'],
#  'house,': ['yeh'],
#  'yeh': ['(woo!)\nMotherfucker,'],
#  '(woo!)\nMotherfucker,': ['nobody'],
#  'nobody': ['knows'],
#  'knows': ['you,'],
#  'you,': ['not'],
#  'not': ['even', 'high,'],
#  'even': ['in'],
#  'Plaza': ['(no)\nThe'],
#  '(no)\nThe': ['Devil'],
#  'Devil': ['calls'],
#  'calls': ['me'],
#  'Jesus': ['Christ'],
#  'Christ': ['hugs'],
#  'hugs': ['me'],
#  '(amen)\nGuerrero': ['like'],
#  'Eddie,': ['long'],
#  'long': ['live'],
#  'live': ['the'],
#  'race': ['(yeh)\nI'],
#  '(yeh)\nI': ['like'],
#  'Boricuas,': ['I'],
#  'Cubans': ['[whistling]\nI'],
#  '[whistling]\nI': ['like'],
#  'accent': ['of'],
#  'Colombians': ["(what's"],
#  "(what's": ['going', 'up?)\nHow'],
#  'on?)\nI': ['like'],
#  'how': ['she'],
#  'she': ['shakes'],
#  'shakes': ['the'],
#  'ass': ['the'],
#  'Dominican': ["(what's"],
#  'up?)\nHow': ['good'],
#  'good': ['they'],
#  'fuck': ['me'],
#  'Venezuelans': ['(woo!)\nWe'],
#  '(woo!)\nWe': ['are'],
#  'are': ['active,'],
#  'active,': ['Perico'],
#  'Perico': ['Pin'],
#  'Pin': ['Pin', '(woo)\nHundred'],
#  '(woo)\nHundred': ['dollar'],
#  'bills': ['in'],
#  'briefcase': ['(ching)\nLet'],
#  '(ching)\nLet': ['the'],
#  'bass': ['resound,'],
#  'resound,': ['Bobby'],
#  'Bobby': ['Valentin,'],
#  'Valentin,': ['yeh\nLove'],
#  'yeh\nLove': ['is'],
#  'forbidden': ['here,'],
#  'here,': ['tell'],
#  'them,': ['Charytín\nFor'],
#  'Charytín\nFor': ['their'],
#  'their': ['itching'],
#  'itching': ['I'],
#  'Claritin\nI': ['arrive'],
#  'arrive': ['at'],
#  'at': ['the'],
#  'riot': ['begins\n\n[Chorus:'],
#  'begins\n\n[Chorus:': ['Cardi'],
#  'B': ['&'],
#  '&': ['Bad', 'Cardi'],
#  'Bunny]\nDiamond': ['district'],
#  'Bunny,': ['baby,'],
#  'be,': ['be,', 'be,', 'be\nCertified,'],
#  'be\nCertified,': ['know'],
#  'that)\nOh,': ["he's"],
#  'it)\nOh,': ['I'],
#  'it)\n\n[Verse': ['3:'],
#  '3:': ['J'],
#  'J': ['Balvin]\nLike', 'Balvin'],
#  'Balvin]\nLike': ['Celia'],
#  'Celia': ['Cruz'],
#  'Cruz': ['I'],
#  'sugar': ['(sugar)\nYour'],
#  '(sugar)\nYour': ['girl'],
#  'girl': ['saw'],
#  'saw': ['me'],
#  'fell': ['forward'],
#  'forward': ['like'],
#  'Jimmy': ['Snuka'],
#  'Snuka': ['(ah)\nWe'],
#  '(ah)\nWe': ['gonna'],
#  'gonna': ['knock', 'pass'],
#  'knock': ['off'],
#  'off': ['your'],
#  'your': ['wig\nAnd', 'head'],
#  'wig\nAnd': ['go'],
#  'go': ['to', 'you'],
#  'hell,': ['motherfucker,'],
#  'motherfucker,': ['we'],
#  'we': ["aren't"],
#  "aren't": ['gonna'],
#  'pass': ['you'],
#  'hookah': ['(hookah,'],
#  '(hookah,': ['hookah)\nMy'],
#  'hookah)\nMy': ['Balenciaga'],
#  'Balenciaga': ['shoes,'],
#  'shoes,': ['they'],
#  'receive': ['me'],
#  'entrance': ['(woo)\nPa-pa-pa-pa-razzi,'],
#  '(woo)\nPa-pa-pa-pa-razzi,': ['like'],
#  'Lady': ['Gaga'],
#  'Gaga': ['(woo)\nAnd'],
#  '(woo)\nAnd': ["don't"],
#  'play': ['dumb'],
#  'dumb': ['(hey),'],
#  '(hey),': ['in'],
#  'covers': ['of'],
#  'Billboard': ['you'],
#  'seen': ['me'],
#  '(hey)\nI': ["don't"],
#  'leave': ['your'],
#  'head': ['(woo)\nEverywhere'],
#  '(woo)\nEverywhere': ['you'],
#  'heard': ['"Mi'],
#  '"Mi': ['Gente"\nI\'m'],
#  'Gente"\nI\'m': ['not'],
#  'high,': ["I'm"],
#  'Testarossa': ["('rossa)\nI'm"],
#  "('rossa)\nI'm": ['the'],
#  'one': ['who', 'who', 'who'],
#  'who': ['lives', 'looks', 'touches'],
#  'lives': ['it'],
#  'enjoys': ['it', "it)\nThat's", '(enjoys,'],
#  '(enjoys': ['it,'],
#  'it,': ['enjoys'],
#  "it)\nThat's": ['the'],
#  'thing,': ['baby'],
#  'baby': ["that's"],
#  "that's": ['the'],
#  'thing': ['(thing,'],
#  '(thing,': ['thing)\nThe'],
#  'thing)\nThe': ['one'],
#  'looks': ['suffers'],
#  'suffers': ['and'],
#  'touches': ['enjoys'],
#  '(enjoys,': ['enjoys)\n\n[Bridge:'],
#  'enjoys)\n\n[Bridge:': ['J'],
#  'Balvin': ['&'],
#  'B]\nI': ['said'],
#  'that\nI': ['said'],
#  '(rrr)\nI': ['said'],
#  '(woo)\nI': ['said'],
#  'that\n\n[Chorus:': ['Cardi'],
#  'brains,': ['wouh'],
#  'wouh': ['(I']}

# %% [markdown]
# # Text Generator

# %% [raw]
# What we need? Dictionary we just created, Number of words we want created

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(cardi_dict)
# Out:
# 'In the riot begins\n\n[Chorus: Cardi Bardi, banging body\nSpicy mami, hot tamale\nHotter than a Somali, fur.'
