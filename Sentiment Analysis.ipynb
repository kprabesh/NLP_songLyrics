# %% [markdown]
# # Sentiment Analysis

# %% [raw]
# Order of the text is important during sentiment analysis. In document term matrix, order is not preserved but in a corpus it is. So, we will use corpus as our imput.

# %% [markdown]
# Researchers have labelled words based on their domain expertise. We will be using this model, namely text blob module for our work.
# Using this model we get the results under two parameters:
# 1. subjectivity( ranges from 0 to +1)
# 2. polarity (ranges from -1 to +1)
#
# For further reading on how textblob is coded, follow this link.
# https://planspace.org/20150607-textblob_sentiment/

# %%
import pandas as pd
data = pd.read_pickle('corpus.pkl')

# %%
from textblob import TextBlob

pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity

data['polarity'] = data['Lyrics'].apply(pol)
data['subjectivity'] = data['Lyrics'].apply(sub)

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]
song_names = ['327', 'Block Party', 'Dangerookipawaa freestyle', 'Leader of Delinquents', 'Shape of you']
index=['Lyrics','polariry','subjectivity']
for index, song in enumerate(data.index):
    x = data.polarity.loc[song]
    y = data.subjectivity.loc[song]
    plt.scatter(x, y, color='blue')
    plt.text(x-0.001, y+0.001, song_names[index], fontsize=10)
    plt.xlim(0, 1) 
    
plt.title('Sentiment Analysis', fontsize=20)
plt.xlabel('<-- Negative -------- Positive -->', fontsize=15)
plt.ylabel('<-- Facts -------- Opinions -->', fontsize=15)

plt.show()

# %% [raw]
# Findings:
# 1. Surprisingly, all four of the rap songs have positive polarity.
# 2. Shape of you is the most positive polar song.
#
# Not very interesting analysis from sentiment analysis. Perhaps analysis of setiment over time throughout the songs would be more insightful?
